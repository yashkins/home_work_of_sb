# %%
# !env\Scripts\activate

# %%
from datetime import datetime as dt

# %%
from work_sqlite import *

# %%
import pandas as pd

# %%
timetable = pd.read_excel('Книга2.xlsx')
# Out:
# c:\lessons\home_work_of_sb\env\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
timetable = timetable.iloc[19:38]

# %%
timetable
# Out:
#    Дальневосточный банк          Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 19                    1    Безматерных Л.В.      ст. кассир        NaN
# 20                    2       Гуринова И.В.     зав. кассой      10.75
# 21                    3       Дуринова О.Е.          кассир        NaN
# 22                    4    Духовникова С.С.      ст. кассир        NaN
# 23                    6        Котлова Е.О.     зав. кассой       1.17
# 24                    7      Махлепова О.С.      ст. кассир      10.25
# 25                    8    Овсянникова О.В.      ст. кассир        NaN
# 26                    9      Пастюхова И.А.      нач. смены      10.25
# 27                   10      Рыбалкина В.В.      ст. кассир          О
# 28                   11        Смолина Е.А.      ст. кассир      11.08
# 29                   12      Степанова Е.А.          кассир       6.75
# 30                   13        Тумаева О.В.      ст. кассир      10.75
# 31                   14       Фильшина А.В.     зав. кассой       6.42
# 32                   15        Цирулик И.В.      ст. кассир       6.75
# 33                   16            Чак Л.А.      нач. смены        NaN
# 34                   17   Чередниченко Г.Н.     зав. кассой        NaN
# 35                   18         Жумова Т.Ю.  гл. специалист         10
# 36                   19  Баймухаметова Е.И.      ст. кассир        NaN
# 37                   20          Бойко А.В.     нач. отдела        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 19      10.92      10.75        NaN        NaN      10.75      10.75  ...
# 20        NaN        NaN        NaN       0.67      10.75      10.75  ...
# 21        NaN        NaN      10.75        NaN        NaN       8.75  ...
# 22      10.75        NaN        NaN        NaN       1.75       9.75  ...
# 23      11.42      11.75        NaN        7.5        NaN       9.08  ...
# 24        NaN        NaN        NaN      10.75      10.25        NaN  ...
# 25        NaN       8.92       9.25        NaN        NaN        NaN  ...
# 26      10.25        NaN        NaN       9.42       9.92        NaN  ...
# 27          О          О          О          О          О          О  ...
# 28      10.75        NaN        NaN      10.75      10.25        NaN  ...
# 29      10.75      10.75        NaN        NaN      10.75      10.67  ...
# 30        NaN        NaN        NaN      10.75        NaN        NaN  ...
# 31        NaN       1.17      11.42      11.33        NaN          1  ...
# 32        NaN      10.75      10.75        NaN        NaN        NaN  ...
# 33        NaN      10.25      10.58        NaN        NaN       8.42  ...
# 34        NaN        NaN       6.67       7.33       5.92        NaN  ...
# 35        NaN        8.5        9.5        NaN          9        NaN  ...
# 36       8.25          О          О          О          О          О  ...
# 37        NaN        NaN        NaN        NaN        NaN        NaN  ...
#
#    Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# 19       10.85         NaN         NaN       162.2         128        34.2
# 20         NaN         NaN        1.83      142.84         128       14.84
# 21         NaN         NaN           5      125.25         128       -2.75
# 22         NaN          12         NaN      141.83         128       13.83
# 23        2.17       12.25       12.42       162.1         128        34.1
# 24           О           О           О       31.25           0       31.25
# 25         NaN         NaN       10.75      141.42         128       13.42
# 26       10.25       10.92         NaN      116.84          88       28.84
# 27        10.5       10.75         NaN      117.92         120       -2.08
# 28       10.58         NaN         NaN      162.25         128       34.25
# 29         NaN       10.75           4         165         128          37
# 30         NaN        5.75         NaN       91.09          72       19.09
# 31       12.67         NaN         NaN      154.17         128       26.17
# 32         NaN         NaN           4      153.33         128       25.33
# 33         NaN         NaN       11.58      142.16         128       14.16
# 34       12.25         NaN         NaN      135.42         128        7.42
# 35        8.75        7.75         NaN      155.08         128       27.08
# 36         NaN         NaN       10.92       59.84          48       11.84
# 37           Д           Д           Д           8           8           0
#
#    Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40
# 19         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN
# 36         NaN         NaN         NaN         NaN
# 37         NaN         NaN         NaN         NaN
#
# [19 rows x 41 columns]

# %%
schedule ={}

# %%
month = 12
year = 2022

# %%
for i in range(len(timetable)):
    series = timetable.iloc[i]
    name = series[1]
    schedule[name] = []
    only_days = series['Unnamed: 3':'Unnamed: 33']
    for count, elem in enumerate(only_days, 1):
        #print(f'{j}: {only_days[j]}: {type(only_days[j])}')
        if isinstance(elem, float | int) and elem > 0:
            schedule[name].append(dt.strptime(f'{count}.{month}.{year}', '%d.%m.%Y'))

# %%
schedule
# Out:
# {'Безматерных Л.В.': [datetime.datetime(2022, 12, 2, 0, 0),
#   datetime.datetime(2022, 12, 3, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 7, 0, 0),
#   datetime.datetime(2022, 12, 10, 0, 0),
#   datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 14, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 18, 0, 0),
#   datetime.datetime(2022, 12, 19, 0, 0),
#   datetime.datetime(2022, 12, 20, 0, 0),
#   datetime.datetime(2022, 12, 23, 0, 0),
#   datetime.datetime(2022, 12, 26, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0)],
#  'Гуринова И.В.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 5, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 7, 0, 0),
#   datetime.datetime(2022, 12, 9, 0, 0),
#   datetime.datetime(2022, 12, 10, 0, 0),
#   datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 14, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 19, 0, 0),
#   datetime.datetime(2022, 12, 20, 0, 0),
#   datetime.datetime(2022, 12, 21, 0, 0),
#   datetime.datetime(2022, 12, 25, 0, 0),
#   datetime.datetime(2022, 12, 26, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 31, 0, 0)],
#  'Дуринова О.Е.': [datetime.datetime(2022, 12, 4, 0, 0),
#   datetime.datetime(2022, 12, 7, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 12, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 16, 0, 0),
#   datetime.datetime(2022, 12, 19, 0, 0),
#   datetime.datetime(2022, 12, 20, 0, 0),
#   datetime.datetime(2022, 12, 24, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 28, 0, 0),
#   datetime.datetime(2022, 12, 31, 0, 0)],
#  'Духовникова С.С.': [datetime.datetime(2022, 12, 2, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 7, 0, 0),
#   datetime.datetime(2022, 12, 10, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 14, 0, 0),
#   datetime.datetime(2022, 12, 17, 0, 0),
#   datetime.datetime(2022, 12, 18, 0, 0),
#   datetime.datetime(2022, 12, 19, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 23, 0, 0),
#   datetime.datetime(2022, 12, 26, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 30, 0, 0)],
#  'Котлова Е.О.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 2, 0, 0),
#   datetime.datetime(2022, 12, 3, 0, 0),
#   datetime.datetime(2022, 12, 5, 0, 0),
#   datetime.datetime(2022, 12, 7, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 12, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 16, 0, 0),
#   datetime.datetime(2022, 12, 19, 0, 0),
#   datetime.datetime(2022, 12, 20, 0, 0),
#   datetime.datetime(2022, 12, 24, 0, 0),
#   datetime.datetime(2022, 12, 25, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0),
#   datetime.datetime(2022, 12, 30, 0, 0),
#   datetime.datetime(2022, 12, 31, 0, 0)],
#  'Махлепова О.С.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 5, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0)],
#  'Овсянникова О.В.': [datetime.datetime(2022, 12, 3, 0, 0),
#   datetime.datetime(2022, 12, 4, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 9, 0, 0),
#   datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 12, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 16, 0, 0),
#   datetime.datetime(2022, 12, 20, 0, 0),
#   datetime.datetime(2022, 12, 21, 0, 0),
#   datetime.datetime(2022, 12, 24, 0, 0),
#   datetime.datetime(2022, 12, 25, 0, 0),
#   datetime.datetime(2022, 12, 28, 0, 0),
#   datetime.datetime(2022, 12, 31, 0, 0)],
#  'Пастюхова И.А.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 2, 0, 0),
#   datetime.datetime(2022, 12, 5, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 17, 0, 0),
#   datetime.datetime(2022, 12, 18, 0, 0),
#   datetime.datetime(2022, 12, 21, 0, 0),
#   datetime.datetime(2022, 12, 25, 0, 0),
#   datetime.datetime(2022, 12, 26, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0),
#   datetime.datetime(2022, 12, 30, 0, 0)],
#  'Рыбалкина В.В.': [datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 14, 0, 0),
#   datetime.datetime(2022, 12, 17, 0, 0),
#   datetime.datetime(2022, 12, 18, 0, 0),
#   datetime.datetime(2022, 12, 21, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 25, 0, 0),
#   datetime.datetime(2022, 12, 26, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0),
#   datetime.datetime(2022, 12, 30, 0, 0)],
#  'Смолина Е.А.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 2, 0, 0),
#   datetime.datetime(2022, 12, 5, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 9, 0, 0),
#   datetime.datetime(2022, 12, 10, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 14, 0, 0),
#   datetime.datetime(2022, 12, 17, 0, 0),
#   datetime.datetime(2022, 12, 18, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 24, 0, 0),
#   datetime.datetime(2022, 12, 25, 0, 0),
#   datetime.datetime(2022, 12, 28, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0)],
#  'Степанова Е.А.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 2, 0, 0),
#   datetime.datetime(2022, 12, 3, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 7, 0, 0),
#   datetime.datetime(2022, 12, 10, 0, 0),
#   datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 14, 0, 0),
#   datetime.datetime(2022, 12, 18, 0, 0),
#   datetime.datetime(2022, 12, 19, 0, 0),
#   datetime.datetime(2022, 12, 21, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 26, 0, 0),
#   datetime.datetime(2022, 12, 30, 0, 0),
#   datetime.datetime(2022, 12, 31, 0, 0)],
#  'Тумаева О.В.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 5, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 9, 0, 0),
#   datetime.datetime(2022, 12, 12, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 16, 0, 0),
#   datetime.datetime(2022, 12, 17, 0, 0),
#   datetime.datetime(2022, 12, 30, 0, 0)],
#  'Фильшина А.В.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 3, 0, 0),
#   datetime.datetime(2022, 12, 4, 0, 0),
#   datetime.datetime(2022, 12, 5, 0, 0),
#   datetime.datetime(2022, 12, 7, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 9, 0, 0),
#   datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 12, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 16, 0, 0),
#   datetime.datetime(2022, 12, 17, 0, 0),
#   datetime.datetime(2022, 12, 21, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 23, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 28, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0)],
#  'Цирулик И.В.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 3, 0, 0),
#   datetime.datetime(2022, 12, 4, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 9, 0, 0),
#   datetime.datetime(2022, 12, 11, 0, 0),
#   datetime.datetime(2022, 12, 12, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 16, 0, 0),
#   datetime.datetime(2022, 12, 20, 0, 0),
#   datetime.datetime(2022, 12, 21, 0, 0),
#   datetime.datetime(2022, 12, 23, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 28, 0, 0),
#   datetime.datetime(2022, 12, 31, 0, 0)],
#  'Чак Л.А.': [datetime.datetime(2022, 12, 3, 0, 0),
#   datetime.datetime(2022, 12, 4, 0, 0),
#   datetime.datetime(2022, 12, 7, 0, 0),
#   datetime.datetime(2022, 12, 8, 0, 0),
#   datetime.datetime(2022, 12, 12, 0, 0),
#   datetime.datetime(2022, 12, 15, 0, 0),
#   datetime.datetime(2022, 12, 16, 0, 0),
#   datetime.datetime(2022, 12, 19, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 23, 0, 0),
#   datetime.datetime(2022, 12, 24, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 28, 0, 0),
#   datetime.datetime(2022, 12, 31, 0, 0)],
#  'Чередниченко Г.Н.': [datetime.datetime(2022, 12, 4, 0, 0),
#   datetime.datetime(2022, 12, 5, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 9, 0, 0),
#   datetime.datetime(2022, 12, 10, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 14, 0, 0),
#   datetime.datetime(2022, 12, 17, 0, 0),
#   datetime.datetime(2022, 12, 18, 0, 0),
#   datetime.datetime(2022, 12, 19, 0, 0),
#   datetime.datetime(2022, 12, 20, 0, 0),
#   datetime.datetime(2022, 12, 23, 0, 0),
#   datetime.datetime(2022, 12, 24, 0, 0),
#   datetime.datetime(2022, 12, 25, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0)],
#  'Жумова Т.Ю.': [datetime.datetime(2022, 12, 1, 0, 0),
#   datetime.datetime(2022, 12, 3, 0, 0),
#   datetime.datetime(2022, 12, 4, 0, 0),
#   datetime.datetime(2022, 12, 6, 0, 0),
#   datetime.datetime(2022, 12, 9, 0, 0),
#   datetime.datetime(2022, 12, 10, 0, 0),
#   datetime.datetime(2022, 12, 13, 0, 0),
#   datetime.datetime(2022, 12, 14, 0, 0),
#   datetime.datetime(2022, 12, 17, 0, 0),
#   datetime.datetime(2022, 12, 18, 0, 0),
#   datetime.datetime(2022, 12, 21, 0, 0),
#   datetime.datetime(2022, 12, 22, 0, 0),
#   datetime.datetime(2022, 12, 25, 0, 0),
#   datetime.datetime(2022, 12, 26, 0, 0),
#   datetime.datetime(2022, 12, 29, 0, 0),
#   datetime.datetime(2022, 12, 30, 0, 0)],
#  'Баймухаметова Е.И.': [datetime.datetime(2022, 12, 2, 0, 0),
#   datetime.datetime(2022, 12, 23, 0, 0),
#   datetime.datetime(2022, 12, 24, 0, 0),
#   datetime.datetime(2022, 12, 27, 0, 0),
#   datetime.datetime(2022, 12, 28, 0, 0),
#   datetime.datetime(2022, 12, 31, 0, 0)],
#  'Бойко А.В.': [datetime.datetime(2022, 12, 10, 0, 0)]}

# %%
losses = pd.read_excel('Книга1.xlsx')

# %%
losses
# Out:
#       выписка за период с 01/01/22 по 02/12/22| Unnamed: 1 Unnamed: 2  \
# 0                                         Номер       Дата       Счет
# 1                                           NaN   24/01/22        NaN
# 2                                           NaN   01/03/22        NaN
# 3                                           NaN   24/01/22        NaN
# 4                                           NaN   14/01/22        NaN
# ...                                         ...        ...        ...
# 71784                                       NaN   02/12/22        NaN
# 71785                                       NaN   02/12/22        NaN
# 71786                                       NaN   02/12/22        NaN
# 71787                                       NaN   02/12/22        NaN
# 71788                                       NaN   02/12/22        NaN
#
#       Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# 0           Корр         ДК       СУМВ       СУМР  Плательщик
# 1            NaN        NaN        NaN        100         NaN
# 2            NaN        NaN        NaN        200         NaN
# 3            NaN        NaN        NaN        400         NaN
# 4            NaN        NaN        NaN       1000         NaN
# ...          ...        ...        ...        ...         ...
# 71784        NaN        NaN        NaN       8400         NaN
# 71785        NaN        NaN        NaN        400         NaN
# 71786        NaN        NaN        NaN       2100         NaN
# 71787        NaN        NaN        NaN        700         NaN
# 71788        NaN        NaN        NaN    1783000         NaN
#
#                Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0      Назначение платежа      БалСЧ  ...         ВАЛ         ВИД     НОМ_ДОК
# 1                     NaN        NaN  ...         RUR         NaN         NaN
# 2                     NaN        NaN  ...         RUR         NaN         NaN
# 3                     NaN        NaN  ...         RUR         NaN         NaN
# 4                     NaN        NaN  ...         RUR         NaN         NaN
# ...                   ...        ...  ...         ...         ...         ...
# 71784                 NaN        NaN  ...         RUR         NaN         NaN
# 71785                 NaN        NaN  ...         RUR         NaN         NaN
# 71786                 NaN        NaN  ...         RUR         NaN         NaN
# 71787                 NaN        NaN  ...         RUR         NaN         NaN
# 71788                 NaN        NaN  ...         RUR         NaN         NaN
#
#       Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17     Unnamed: 18  \
# 0             ИСХ         КНП      Создал  Наим.Счета  Наим.Владельца
# 1             NaN         NaN         NaN         NaN             NaN
# 2             NaN         NaN         NaN         NaN             NaN
# 3             NaN         NaN         NaN         NaN             NaN
# 4             NaN         NaN         NaN         NaN             NaN
# ...           ...         ...         ...         ...             ...
# 71784         NaN         NaN         NaN         NaN             NaN
# 71785         NaN         NaN         NaN         NaN             NaN
# 71786         NaN         NaN         NaN         NaN             NaN
# 71787         NaN         NaN         NaN         NaN             NaN
# 71788         NaN         NaN         NaN         NaN             NaN
#
#       Unnamed: 19                                     Unnamed: 20
# 0      Подр.отчет  Ошибки и корректировки предшествующего периода
# 1             NaN                                             NaN
# 2             NaN                                             NaN
# 3             NaN                                             NaN
# 4             NaN                                             NaN
# ...           ...                                             ...
# 71784         NaN                                             NaN
# 71785         NaN                                             NaN
# 71786         NaN                                             NaN
# 71787         NaN                                             NaN
# 71788         NaN                                             NaN
#
# [71789 rows x 21 columns]

# %%
losses = losses.loc[1:71788]

# %%
losses['Unnamed: 1']
# Out:
# 1        24/01/22
# 2        01/03/22
# 3        24/01/22
# 4        14/01/22
# 5        14/01/22
#            ...
# 71784    02/12/22
# 71785    02/12/22
# 71786    02/12/22
# 71787    02/12/22
# 71788    02/12/22
# Name: Unnamed: 1, Length: 71788, dtype: object

# %%
for i in range(len(losses)):
            losses['Unnamed: 1'].iloc[i] = dt.strptime(losses['Unnamed: 1'].iloc[i],'%d/%m/%y')
# Out:
# C:\Users\яков\AppData\Local\Temp\ipykernel_11992\3930886615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   losses['Unnamed: 1'].iloc[i] = dt.strptime(losses['Unnamed: 1'].iloc[i],'%d/%m/%y')

# %%
losses
# Out:
#       выписка за период с 01/01/22 по 02/12/22|           Unnamed: 1  \
# 1                                           NaN  2022-01-24 00:00:00
# 2                                           NaN  2022-03-01 00:00:00
# 3                                           NaN  2022-01-24 00:00:00
# 4                                           NaN  2022-01-14 00:00:00
# 5                                           NaN  2022-01-14 00:00:00
# ...                                         ...                  ...
# 71784                                       NaN  2022-12-02 00:00:00
# 71785                                       NaN  2022-12-02 00:00:00
# 71786                                       NaN  2022-12-02 00:00:00
# 71787                                       NaN  2022-12-02 00:00:00
# 71788                                       NaN  2022-12-02 00:00:00
#
#       Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 1            NaN        NaN        NaN        NaN        100        NaN
# 2            NaN        NaN        NaN        NaN        200        NaN
# 3            NaN        NaN        NaN        NaN        400        NaN
# 4            NaN        NaN        NaN        NaN       1000        NaN
# 5            NaN        NaN        NaN        NaN       1000        NaN
# ...          ...        ...        ...        ...        ...        ...
# 71784        NaN        NaN        NaN        NaN       8400        NaN
# 71785        NaN        NaN        NaN        NaN        400        NaN
# 71786        NaN        NaN        NaN        NaN       2100        NaN
# 71787        NaN        NaN        NaN        NaN        700        NaN
# 71788        NaN        NaN        NaN        NaN    1783000        NaN
#
#       Unnamed: 8 Unnamed: 9  ... Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 1            NaN        NaN  ...         RUR         NaN         NaN
# 2            NaN        NaN  ...         RUR         NaN         NaN
# 3            NaN        NaN  ...         RUR         NaN         NaN
# 4            NaN        NaN  ...         RUR         NaN         NaN
# 5            NaN        NaN  ...         RUR         NaN         NaN
# ...          ...        ...  ...         ...         ...         ...
# 71784        NaN        NaN  ...         RUR         NaN         NaN
# 71785        NaN        NaN  ...         RUR         NaN         NaN
# 71786        NaN        NaN  ...         RUR         NaN         NaN
# 71787        NaN        NaN  ...         RUR         NaN         NaN
# 71788        NaN        NaN  ...         RUR         NaN         NaN
#
#       Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# 5             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 71784         NaN         NaN         NaN         NaN         NaN         NaN
# 71785         NaN         NaN         NaN         NaN         NaN         NaN
# 71786         NaN         NaN         NaN         NaN         NaN         NaN
# 71787         NaN         NaN         NaN         NaN         NaN         NaN
# 71788         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 20
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# ...           ...
# 71784         NaN
# 71785         NaN
# 71786         NaN
# 71787         NaN
# 71788         NaN
#
# [71788 rows x 21 columns]

# %%
list_losses = [(losses['Unnamed: 1'].iloc[i], float(losses['Unnamed: 6'].iloc[i])) for i in range(len(losses))]

# %%
list_losses
# Out:
# [(datetime.datetime(2022, 1, 24, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 1, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 7000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 9000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 4500.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 7, 0, 0), 500.0),
#  (datetime.datetime(2022, 2, 7, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1900.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1100.0),
#  (datetime.datetime(2022, 2, 18, 0, 0), 16000.0),
#  (datetime.datetime(2022, 2, 25, 0, 0), 2000.0),
#  (datetime.datetime(2022, 3, 3, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 900.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1850.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 1570.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 4700.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1300.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 4300.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 650.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1500.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 600.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1300.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 15000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 28, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 4900.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 21, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 3, 3, 0, 0), 1600.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 3, 0, 0), 5000.0),
#  (datetime.datetime(2022, 3, 5, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 260.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 4100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 4600.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 13800.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 7400.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 950.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 62200.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 42000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 3, 3, 0, 0), 4650.0),
#  (datetime.datetime(2022, 2, 14, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 17100.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 29400.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1200.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 9, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 400000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 500.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 40000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1600.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 1500.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 341650.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 483250.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 1156000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 398800.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 398800.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 398800.0),
#  (datetime.datetime(2022, 2, 4, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 16000.0),
#  (datetime.datetime(2022, 2, 7, 0, 0), 2700.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 192000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 900.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 20000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 4470000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 25000.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 1000.0),
#  (datetime.datetime(2022, 3, 10, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 26700.0),
#  (datetime.datetime(2022, 2, 14, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 26, 0, 0), 4000.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 1200.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 4600.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 9000.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 130000.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 1095500.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 4500.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 1500.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 295150.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 17100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 356300.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 1497000.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 10000.0),
#  (datetime.datetime(2022, 3, 9, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 6700.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 1523700.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 60000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 1076750.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 20000.0),
#  (datetime.datetime(2022, 3, 9, 0, 0), 4500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 165550.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 13000.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 15000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 24800.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 9900.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 2100.0),
#  (datetime.datetime(2022, 2, 25, 0, 0), 8500.0),
#  (datetime.datetime(2022, 2, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 256800.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 930000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 3500.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 2400.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 109500.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 630400.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 126500.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 776500.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 2088000.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 834100.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 30000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 40000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 262500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 262500.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 64300.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 64300.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 19000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 19000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 1181500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 1181500.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 1500000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 1500000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 1468800.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 1468800.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 208900.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 157900.0),
#  (datetime.datetime(2022, 2, 25, 0, 0), 51000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 86400.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 25000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 11400.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 50000.0),
#  (datetime.datetime(2022, 5, 23, 0, 0), 11400.0),
#  (datetime.datetime(2022, 5, 25, 0, 0), 11400.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 6910000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 6910000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 2419000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 2149000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 270000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 104000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 100000.0),
#  (datetime.datetime(2022, 2, 8, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 4000.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 21600.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 21600.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 150000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 150000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 1000000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 504000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 496000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 14000.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 14000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 8000.0),
#  (datetime.datetime(2022, 1, 28, 0, 0), 8000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 5000.0),
#  (datetime.datetime(2022, 3, 3, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 500.0),
#  (datetime.datetime(2022, 2, 3, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 1, 0, 0), 703750.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 703750.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 21600.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 21600.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 433050.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 404050.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 29000.0),
#  (datetime.datetime(2022, 1, 28, 0, 0), 403050.0),
#  (datetime.datetime(2022, 1, 28, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 28, 0, 0), 404050.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 62500.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 62500.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 57800.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 57800.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 700.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 700.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 50000.0),
#  (datetime.datetime(2022, 2, 8, 0, 0), 50000.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 1046400.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 1046400.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 131900.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 131900.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 564350.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 564350.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 44000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 44000.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 98000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 98000.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 23000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 23000.0),
#  (datetime.datetime(2022, 1, 2, 0, 0), 302400.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 12000.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 238400.0),
#  (datetime.datetime(2022, 2, 8, 0, 0), 47000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 99000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 99000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 1000.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 5000.0),
#  (datetime.datetime(2022, 3, 5, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 2620000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 2620000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 6500.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 6500.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 2800.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 2800.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 42000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 36000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 111850.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 111850.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 500.0),
#  (datetime.datetime(2022, 3, 28, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 20000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 20000.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 28, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 54300.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 54300.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 105000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 105000.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 5462600.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5462600.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 400.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 4, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 535000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 535000.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 600.0),
#  (datetime.datetime(2022, 2, 8, 0, 0), 600.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 2000.0),
#  (datetime.datetime(2022, 3, 9, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 2361100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 2361100.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 644000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 644000.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 3, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 47000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 47000.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 1165900.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1165900.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 395000.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 395000.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 100.0),
#  (datetime.datetime(2022, 5, 23, 0, 0), 100.0),
#  (datetime.datetime(2022, 5, 31, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 200.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 200.0),
#  (datetime.datetime(2022, 5, 23, 0, 0), 200.0),
#  (datetime.datetime(2022, 5, 31, 0, 0), 100.0),
#  (datetime.datetime(2022, 5, 31, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 168250.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 168250.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 4800.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 4800.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 1300.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 1300.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 7500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 2400.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 5100.0),
#  (datetime.datetime(2022, 1, 5, 0, 0), 50000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 50000.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 123600.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 122600.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 528650.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 521900.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 6750.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 242150.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 242000.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 150.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 110000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 110000.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 65000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 45000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 20000.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 41100.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 41100.0),
#  (datetime.datetime(2022, 1, 6, 0, 0), 39600.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 39600.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 500.0),
#  (datetime.datetime(2022, 3, 28, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 907600.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 907600.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 1100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 1000.0),
#  (datetime.datetime(2022, 3, 4, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 9950.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 2331300.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 2331300.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 7, 0, 0), 254900.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 254900.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 9900.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 9900.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 10100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 6350.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 3550.0),
#  (datetime.datetime(2022, 2, 9, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 17200.0),
#  (datetime.datetime(2022, 2, 4, 0, 0), 17200.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 7500.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 7500.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 97350.0),
#  (datetime.datetime(2022, 2, 14, 0, 0), 4000.0),
#  (datetime.datetime(2022, 2, 14, 0, 0), 6000.0),
#  (datetime.datetime(2022, 2, 14, 0, 0), 86350.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 8, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 178350.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 178350.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 50800.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 50800.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 5200.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 5200.0),
#  (datetime.datetime(2022, 1, 9, 0, 0), 200.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 88300.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 88300.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 28, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 195000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 159500.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 35500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 4500.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 4500.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 2200.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 2200.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 1650000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1650000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 200.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 1047100.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1047100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 67350.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 67350.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 102300.0),
#  (datetime.datetime(2022, 1, 21, 0, 0), 102300.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 8000.0),
#  (datetime.datetime(2022, 2, 11, 0, 0), 8000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 500.0),
#  (datetime.datetime(2022, 3, 28, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 381000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 381000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 213950.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 213950.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 93900.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 93900.0),
#  (datetime.datetime(2022, 1, 10, 0, 0), 2200.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 2200.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 3324300.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 3024300.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 300000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 2600.0),
#  (datetime.datetime(2022, 3, 5, 0, 0), 2600.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 200.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 270000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 270000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 232600.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 232600.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 1485000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1485000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 11000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 11000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 6000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 6000.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 5000.0),
#  (datetime.datetime(2022, 3, 2, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 500.0),
#  (datetime.datetime(2022, 3, 28, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 1250.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 550.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 200.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 11, 0, 0), 54900.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 54900.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 177850.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 177850.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 9500.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 9500.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1000000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1000000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 8000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 8000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 4, 0, 0), 3000.0),
#  (datetime.datetime(2022, 2, 4, 0, 0), 1000.0),
#  (datetime.datetime(2022, 2, 4, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 6200.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 6200.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 500.0),
#  (datetime.datetime(2022, 3, 29, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 20000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 20000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 500.0),
#  (datetime.datetime(2022, 3, 29, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 29, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 3568900.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 3568900.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 103100.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 103100.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 452000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 452000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1800.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1300.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 500.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 274700.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 274700.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 1794750.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1794750.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 7000.0),
#  (datetime.datetime(2022, 2, 14, 0, 0), 7000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 61200.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 61200.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 25000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 24900.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 36500.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 36500.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 778300.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 777300.0),
#  (datetime.datetime(2022, 2, 25, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1000000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 999900.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 3950.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 3950.0),
#  (datetime.datetime(2022, 1, 12, 0, 0), 7000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 7000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1338500.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1338500.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 500.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 60050.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 10050.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 50000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 973350.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 973350.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 1200.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1200.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 29, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1333900.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1333900.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 56500.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 56000.0),
#  (datetime.datetime(2022, 3, 1, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 13, 0, 0), 6600.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 3500.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 3100.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 14100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 14100.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 500.0),
#  (datetime.datetime(2022, 3, 1, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1334900.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1334900.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 29, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 297230.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 297230.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 50000.0),
#  (datetime.datetime(2022, 2, 3, 0, 0), 50000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 1492600.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 1492600.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 2900.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 1500.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 200.0),
#  (datetime.datetime(2022, 3, 29, 0, 0), 1200.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 11350.0),
#  (datetime.datetime(2022, 1, 27, 0, 0), 11350.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 2720000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 2720000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 13000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 13000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 242850.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 106150.0),
#  (datetime.datetime(2022, 2, 3, 0, 0), 136700.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 2156400.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 2156400.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 20000.0),
#  (datetime.datetime(2022, 2, 3, 0, 0), 20000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 5000.0),
#  (datetime.datetime(2022, 3, 2, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 63900.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 63900.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 1000.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 12700.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 12700.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 1567100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1567100.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 1997600.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 1997600.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 3050.0),
#  (datetime.datetime(2022, 3, 9, 0, 0), 1950.0),
#  (datetime.datetime(2022, 1, 14, 0, 0), 7500.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 7500.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 23300.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 23300.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 24, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 6000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 6000.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 1232900.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 1231900.0),
#  (datetime.datetime(2022, 3, 4, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 5100.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 5100.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 18700.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 18700.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 2000.0),
#  (datetime.datetime(2022, 2, 1, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 2500.0),
#  (datetime.datetime(2022, 3, 9, 0, 0), 2500.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 29, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 609300.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 609300.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 15, 0, 0), 68000.0),
#  (datetime.datetime(2022, 1, 31, 0, 0), 67000.0),
#  (datetime.datetime(2022, 3, 5, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 30, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 600.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 600.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 5500.0),
#  (datetime.datetime(2022, 2, 14, 0, 0), 4000.0),
#  (datetime.datetime(2022, 2, 14, 0, 0), 1500.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 4, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 4, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 5, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 16, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 10000.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 1500.0),
#  (datetime.datetime(2022, 3, 3, 0, 0), 5000.0),
#  (datetime.datetime(2022, 3, 10, 0, 0), 3500.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 2000.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 200.0),
#  (datetime.datetime(2022, 3, 4, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 900.0),
#  (datetime.datetime(2022, 3, 5, 0, 0), 500.0),
#  (datetime.datetime(2022, 3, 5, 0, 0), 400.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 7600.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 7600.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 4, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 800.0),
#  (datetime.datetime(2022, 2, 4, 0, 0), 800.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 5000.0),
#  (datetime.datetime(2022, 2, 3, 0, 0), 2000.0),
#  (datetime.datetime(2022, 2, 3, 0, 0), 3000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 300.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 2000.0),
#  (datetime.datetime(2022, 2, 24, 0, 0), 1000.0),
#  (datetime.datetime(2022, 3, 5, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 17, 0, 0), 762950.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 762950.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 50.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 32900.0),
#  (datetime.datetime(2022, 2, 18, 0, 0), 32900.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 51200.0),
#  (datetime.datetime(2022, 2, 3, 0, 0), 51200.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 48300.0),
#  (datetime.datetime(2022, 2, 18, 0, 0), 2300.0),
#  (datetime.datetime(2022, 2, 18, 0, 0), 46000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1550650.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1548650.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 3532800.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 3532800.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 8500.0),
#  (datetime.datetime(2022, 1, 21, 0, 0), 8500.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1767100.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1767100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 6000.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 1000.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 98300.0),
#  (datetime.datetime(2022, 3, 1, 0, 0), 90800.0),
#  (datetime.datetime(2022, 3, 2, 0, 0), 7500.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 8, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 24000.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 24000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 5000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 2000.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 2000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 6000.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 6000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1367150.0),
#  (datetime.datetime(2022, 1, 25, 0, 0), 1367150.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 10000.0),
#  (datetime.datetime(2022, 3, 1, 0, 0), 10000.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 500.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 500.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 75000.0),
#  (datetime.datetime(2022, 1, 21, 0, 0), 75000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 33100.0),
#  (datetime.datetime(2022, 1, 24, 0, 0), 33000.0),
#  (datetime.datetime(2022, 3, 2, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 18, 0, 0), 10600.0),
#  (datetime.datetime(2022, 1, 21, 0, 0), 10600.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 24200.0),
#  (datetime.datetime(2022, 2, 24, 0, 0), 24200.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 200.0),
#  (datetime.datetime(2022, 3, 1, 0, 0), 200.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 21, 0, 0), 4000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 100.0),
#  (datetime.datetime(2022, 2, 28, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 131700.0),
#  (datetime.datetime(2022, 1, 20, 0, 0), 131700.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 21, 0, 0), 1000.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 496600.0),
#  (datetime.datetime(2022, 2, 2, 0, 0), 496600.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 100.0),
#  (datetime.datetime(2022, 3, 4, 0, 0), 100.0),
#  (datetime.datetime(2022, 1, 19, 0, 0), 100.0),
#  ...]

# %%
connect = create_connection('db_for_sb.db')
# Out:
# Соединение установленно

# %%
#execute_query(connect, query) for query in (query_create_emp, query_create_jd, query_create_loss)

# %%
#inserted_employees(connect, query_insert_emp, schedule)

# %%
data = [(name,) for name in schedule]
print(data)
# Out:
# [('Безматерных Л.В.',), ('Гуринова И.В.',), ('Дуринова О.Е.',), ('Духовникова С.С.',), ('Котлова Е.О.',), ('Махлепова О.С.',), ('Овсянникова О.В.',), ('Пастюхова И.А.',), ('Рыбалкина В.В.',), ('Смолина Е.А.',), ('Степанова Е.А.',), ('Тумаева О.В.',), ('Фильшина А.В.',), ('Цирулик И.В.',), ('Чак Л.А.',), ('Чередниченко Г.Н.',), ('Жумова Т.Ю.',), ('Баймухаметова Е.И.',), ('Бойко А.В.',)]

# %%
"""for name in schedule:
    print(name.encode('utf-8').decode('utf-8'))"""
# Out:
# "for name in schedule:\n    print(name.encode('utf-8').decode('utf-8'))"

# %%
def select_empid(connection, query, name):
    cursor = connection.cursor()
    result = None
    descriptions = None
    try:
        cursor.execute(query, (name,))
        descriptions = [descript[0] for descript in cursor.description]
        result = cursor.fetchall()
    except Error as e:
        print(f'Error query: {e}')
    return descriptions, result

# %%
query_select_empid = """SELECT id FROM Employees WHERE name = ?"""

# %%
label, result = select_empid(connect, query_select_empid, "Гуринова И.В.")

# %%
result
# Out:
# [(2,)]

# %%
def insert_Job_Deys(connection, query, values):
    cursor = connection.cursor()
    data = []
    try:
        for name in values:
            column_names, result = select_empid(connection, query_select_empid, name)
            emp_id = result[0][0]
            for date in values[name]:
                data.append((emp_id, date))
        cursor.executemany(query, (data))
        connection.commit()
        print('Запрос выполнен')
    except Error as e:
        print(f'Error query: {e}')

# %%
query_insert_jd = """INSERT INTO Job_Deys(emp_id, date) VALUES (?,?)"""

# %%
#insert_Job_Deys(connect, """INSERT INTO Job_Deys(emp_id, date) VALUES (?,?)""", schedule)

# %%
def execute_read_query(connection, query):
    cursor = connection.cursor()
    result = None
    descriptions = None
    try:
        cursor.execute(query)
        descriptions = [descript[0] for descript in cursor.description]
        result = cursor.fetchall()
    except Error as e:
        print(f'Error query: {e}')
    return descriptions, result

# %%
query_select_result = """SELECT name as ФИО, COUNT(DISTINCT jd.date) as Колличество 
        FROM Employees as emp INNER JOIN Job_Deys as jd ON emp.id = jd.emp_id
        INNER JOIN Losses as loss ON jd.date = loss.date
        GROUP BY name"""

# %%
column_names, values = execute_read_query(connect, query_select_result)

# %%
values
# Out:
# [('Баймухаметова Е.И.', 1),
#  ('Безматерных Л.В.', 1),
#  ('Гуринова И.В.', 1),
#  ('Духовникова С.С.', 1),
#  ('Жумова Т.Ю.', 1),
#  ('Котлова Е.О.', 2),
#  ('Махлепова О.С.', 1),
#  ('Пастюхова И.А.', 2),
#  ('Смолина Е.А.', 2),
#  ('Степанова Е.А.', 2),
#  ('Тумаева О.В.', 1),
#  ('Фильшина А.В.', 1),
#  ('Цирулик И.В.', 1)]

# %%
result = {}
for elem in values:
    for i in range(len(column_names)):
        result[column_names[i]] = result.get(column_names[i],[]) + [elem[i]]

# %%
result
# Out:
# {'ФИО': ['Баймухаметова Е.И.',
#   'Безматерных Л.В.',
#   'Гуринова И.В.',
#   'Духовникова С.С.',
#   'Жумова Т.Ю.',
#   'Котлова Е.О.',
#   'Махлепова О.С.',
#   'Пастюхова И.А.',
#   'Смолина Е.А.',
#   'Степанова Е.А.',
#   'Тумаева О.В.',
#   'Фильшина А.В.',
#   'Цирулик И.В.'],
#  'Колличество': [1, 1, 1, 1, 1, 2, 1, 2, 2, 2, 1, 1, 1]}

# %%
#result_to_excel = pd.DataFrame(result)
#result_to_excel.to_excel('report_distinct.xlsx')

# %%
query_select_date = """SELECT COUNT(loss.date) as Колличество 
        FROM Losses as WHERE loss.date = datetime.datetime(2022, 12, 3, 0, 0)
        """
#column_names, values = execute_read_query(connect, query_select_date)
